# %% [markdown]
# # Test image generator
#
# This little program creates three possible types of a color channel fill: all white, all black and white-to-black gradient. Then it figures out all the possible ways of putting them together and generates test images: some of them plain colored, some with gradient fill.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from skimage import io

# %%
gradient_channel = np.array([np.arange(0,256) for i in range(0,256)], dtype = ('uint8'))

# gradient channel filled with numbers from 0 to 255

# %%
white_channel = np.full((256,256), 255, dtype = ('uint8'))

# white channel filled with 255s

# %%
black_channel = np.zeros((256,256), dtype = ('uint8'))

# black channel filled with zeros

# %%
channels = [gradient_channel, white_channel, black_channel] #list of channels

product = itertools.product([0,1,2], repeat = 3) #create an iterator 

for i in product:

    fig, ax = plt.subplots() # initiate plots 

    #get channels from the channels list based on the tuple generated by the iterator
    
    r = channels[i[0]] 
    g = channels[i[1]]
    b = channels[i[2]]
    
    img = np.stack([r,g,b], axis = 2) # stack the three channels together into a 3D array
    
    title = 'image_'+str(i[0]) + str(i[1]) + str(i[2])
    plt.title(title)
    
    plt.imshow(img)
     
    # io.imsave(title+'.jpg', img) - uncomment if saving needed
    
    plt.show()
